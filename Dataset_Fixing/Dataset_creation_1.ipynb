# %%
import numpy as np
import pandas as pd

# %%
books=pd.read_csv("books_1.Best_Books_Ever.csv")
Book=pd.read_csv("Books.csv")
users = pd.read_csv("Users.csv")
Ratings_users = pd.read_csv("Ratings.csv")
# Out:
# C:\Users\MOHAMMED ABID\AppData\Local\Temp\ipykernel_28652\3201514788.py:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   Book=pd.read_csv("Books.csv")

# %%
Book
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# ...

# %%
users
# Out:
#         User-ID                            Location   Age
# 0             1                  nyc, new york, usa   NaN
# 1             2           stockton, california, usa  18.0
# 2             3     moscow, yukon territory, russia   NaN
# 3             4           porto, v.n.gaia, portugal  17.0
# 4             5  farnborough, hants, united kingdom   NaN
# ...         ...                                 ...   ...
# 278853   278854               portland, oregon, usa   NaN
# 278854   278855  tacoma, washington, united kingdom  50.0
# 278855   278856           brampton, ontario, canada   NaN
# 278856   278857           knoxville, tennessee, usa   NaN
# 278857   278858                dublin, n/a, ireland   NaN
#
# [278858 rows x 3 columns]

# %%
Ratings_users
# Out:
#          User-ID         ISBN  Book-Rating
# 0         276725   034545104X            0
# 1         276726   0155061224            5
# 2         276727   0446520802            0
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# ...          ...          ...          ...
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
# [1149780 rows x 3 columns]

# %%
print(books.shape)
print(Book.shape)
print(Ratings_users.shape)
print(users.shape)
# Out:
# (52478, 25)
# (271360, 8)
# (1149780, 3)
# (278858, 3)

# %%
books.isnull().sum()
# Out:
# bookId                  0
# Book-Title              0
# series              29008
# author                  0
# rating                  0
# description          1338
# language             3806
# ISBN                    0
# genres                  0
# characters              0
# bookFormat           1473
# edition             47523
# pages                2347
# publisher            3696
# publishDate           880
# firstPublishDate    21326
# awards                  0
# numRatings              0
# ratingsByStars          0
# likedPercent          622
# setting                 0
# coverImg              605
# bbeScore                0
# bbeVotes                0
# price               14365
# dtype: int64

# %%
books.duplicated().sum()
# Out:
# 50

# %%
new_books = books.merge(Book,on='Book-Title')
new_books
# Out:
#                              bookId              Book-Title  \
# 0        2657.To_Kill_a_Mockingbird   To Kill a Mockingbird
# 1        2657.To_Kill_a_Mockingbird   To Kill a Mockingbird
# 2        2657.To_Kill_a_Mockingbird   To Kill a Mockingbird
# 3        2657.To_Kill_a_Mockingbird   To Kill a Mockingbird
# 4        2657.To_Kill_a_Mockingbird   To Kill a Mockingbird
# ...                             ...                     ...
# 27186  42923.The_Nightingale_s_Song  The Nightingale's Song
# 27187     96337.The_Conservationist     The Conservationist
# 27188         243854.Vacuum_Flowers          Vacuum Flowers
# 27189          37169.The_Delta_Star          The Delta Star
# 27190              11836711-anasazi                 Anasazi
#
#                       series                              author  rating  \
# 0      To Kill a Mockingbird                          Harper Lee    4.28
# 1      To Kill a Mockingbird                          Harper Lee    4.28
# ...

# %% [markdown]
# ## For the top 10 user rated books

# %%
user_rate = Ratings_users.merge(Book,on = 'ISBN') #Here we are merging the book database with pic with the user ratings dataset

# %%
num_rates = user_rate.groupby('Book-Title').count()['Book-Rating'].reset_index() #Here book rating stands for number of ratings
num_rates
# Out:
#                                                Book-Title  Book-Rating
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.            2
# 241067                     Ã?Â?rger mit Produkt X. Roman.            4
# 241068                                Ã?Â?sterlich leben.            1
# 241069                              Ã?Â?stlich der Berge.            3
# 241070                                  Ã?Â?thique en toc            2
#
# [241071 rows x 2 columns]

# %%
avg_rates = user_rate.groupby('Book-Title').mean()['Book-Rating'].reset_index() 
avg_rates.rename(columns = {'Book-Rating' : 'avg_rating'}, inplace=True) #Here we finding the average number of ratings 
avg_rates
# Out:
#                                                Book-Title  avg_rating
# 0        A Light in the Storm: The Civil War Diary of ...    2.250000
# 1                                   Always Have Popsicles    0.000000
# 2                    Apple Magic (The Collector's series)    0.000000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...    8.000000
# 4        Beyond IBM: Leadership Marketing and Finance ...    0.000000
# ...                                                   ...         ...
# 241066                                      Ã?Â?lpiraten.    0.000000
# 241067                     Ã?Â?rger mit Produkt X. Roman.    5.250000
# 241068                                Ã?Â?sterlich leben.    7.000000
# 241069                              Ã?Â?stlich der Berge.    2.666667
# 241070                                  Ã?Â?thique en toc    4.000000
#
# [241071 rows x 2 columns]

# %%
popul = avg_rates.merge(num_rates,on = 'Book-Title')
popul
# Out:
#                                                Book-Title  avg_rating  \
# 0        A Light in the Storm: The Civil War Diary of ...    2.250000
# 1                                   Always Have Popsicles    0.000000
# 2                    Apple Magic (The Collector's series)    0.000000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...    8.000000
# 4        Beyond IBM: Leadership Marketing and Finance ...    0.000000
# ...                                                   ...         ...
# 241066                                      Ã?Â?lpiraten.    0.000000
# 241067                     Ã?Â?rger mit Produkt X. Roman.    5.250000
# 241068                                Ã?Â?sterlich leben.    7.000000
# 241069                              Ã?Â?stlich der Berge.    2.666667
# 241070                                  Ã?Â?thique en toc    4.000000
#
#         Book-Rating
# 0                 4
# 1                 1
# 2                 1
# 3                 1
# ...

# %%
top_20 = popul[popul['Book-Rating']>=200].sort_values('avg_rating',ascending=False).head(20)
top_20
# Out:
#                                                Book-Title  avg_rating  \
# 80434   Harry Potter and the Prisoner of Azkaban (Book 3)    5.852804
# 80422        Harry Potter and the Goblet of Fire (Book 4)    5.824289
# 80441      Harry Potter and the Sorcerer's Stone (Book 1)    5.737410
# 80426   Harry Potter and the Order of the Phoenix (Boo...    5.501441
# 60582       Ender's Game (Ender Wiggins Saga (Paperback))    5.409639
# 80414    Harry Potter and the Chamber of Secrets (Book 2)    5.183453
# 191612  The Hobbit : The Enchanting Prelude to The Lor...    5.007117
# 187377  The Fellowship of the Ring (The Lord of the Ri...    4.948370
# 80445   Harry Potter and the Sorcerer's Stone (Harry P...    4.895652
# 211384     The Two Towers (The Lord of the Rings, Part 2)    4.880769
# 219741                              To Kill a Mockingbird    4.700000
# 183573                                  The Da Vinci Code    4.642539
# ...

# %%
pop = top_20.merge(Book ,on = 'Book-Title').drop_duplicates('Book-Title')

# %%
pop = pop[['Book-Title','Book-Rating','Book-Author','Image-URL-M']]
pop
# Out:
#                                            Book-Title  Book-Rating  \
# 0   Harry Potter and the Prisoner of Azkaban (Book 3)          428
# 3        Harry Potter and the Goblet of Fire (Book 4)          387
# 5      Harry Potter and the Sorcerer's Stone (Book 1)          278
# 9   Harry Potter and the Order of the Phoenix (Boo...          347
# 13      Ender's Game (Ender Wiggins Saga (Paperback))          249
# 17   Harry Potter and the Chamber of Secrets (Book 2)          556
# 20  The Hobbit : The Enchanting Prelude to The Lor...          281
# 21  The Fellowship of the Ring (The Lord of the Ri...          368
# 30  Harry Potter and the Sorcerer's Stone (Harry P...          575
# 32     The Two Towers (The Lord of the Rings, Part 2)          260
# 43                              To Kill a Mockingbird          510
# 51                                  The Da Vinci Code          898
# 57                 The Five People You Meet in Heaven          430
# ...

# %%
# new_books.to_csv("new_books.csv")
# pop.to_csv("popular_books.csv")

# %% [markdown]
# ## Content based Recommender
