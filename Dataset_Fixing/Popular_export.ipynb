# %%
import pandas as pd
import pickle

# %%
popular = pd.read_csv('popular_books.csv')
popular
# Out:
#     Unnamed: 0                                         Book-Title  \
# 0            0  Harry Potter and the Prisoner of Azkaban (Book 3)
# 1            3       Harry Potter and the Goblet of Fire (Book 4)
# 2            5     Harry Potter and the Sorcerer's Stone (Book 1)
# 3            9  Harry Potter and the Order of the Phoenix (Boo...
# 4           13      Ender's Game (Ender Wiggins Saga (Paperback))
# 5           17   Harry Potter and the Chamber of Secrets (Book 2)
# 6           20  The Hobbit : The Enchanting Prelude to The Lor...
# 7           21  The Fellowship of the Ring (The Lord of the Ri...
# 8           30  Harry Potter and the Sorcerer's Stone (Harry P...
# 9           32     The Two Towers (The Lord of the Rings, Part 2)
# 10          43                              To Kill a Mockingbird
# 11          51                                  The Da Vinci Code
# 12          57                 The Five People You Meet in Heaven
# ...

# %%
popular['Image-URL-M'][0]
# Out:
# 'http://images.amazon.com/images/P/0439136350.01.MZZZZZZZ.jpg'

# %%
pickle.dump(popular,open('pouplar.pkl','wb'))
